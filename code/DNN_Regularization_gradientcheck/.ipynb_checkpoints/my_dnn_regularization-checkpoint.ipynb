# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
import sklearn
import sklearn.datasets
import scipy.io
from testCases import *
# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %load_ext autoreload
# %autoreload 2

np.random.seed(1)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def load_2D_dataset():
    data = scipy.io.loadmat('datasets/data.mat')
    train_X = data['X'].T
    train_Y = data['y'].T
    test_X = data['Xval'].T
    test_Y = data['yval'].T

    plt.scatter(train_X[0, :], train_X[1, :], c=train_Y.ravel(), s=40, cmap=plt.cm.Spectral);
   
    return train_X, train_Y, test_X, test_Y

# %%
train_X, train_Y, test_X, test_Y = load_2D_dataset()

# %%
print(train_X.shape)
print(train_Y.shape)
print(test_X.shape)
print(test_Y.shape)
# Out:
# (2, 211)
# (1, 211)
# (2, 200)
# (1, 200)

# %%
def sigmoid(Z):
    A=1/(1+np.exp(-Z))
    cache=Z
    return A,Z

# %%
def relu(Z):
    A=np.maximum(0,Z)
    cache=Z
    return A,Z

# %%
def initialize_parameter_deep(layer_dims):
    parameters={}
    np.random.seed(3)
    for l in range(1,len(layer_dims)):
        parameters["W"+str(l)]=np.random.randn(layer_dims[l],layer_dims[l-1])/np.sqrt(layer_dims[l-1])
        parameters["b"+str(l)]=np.zeros((layer_dims[l],1))
    
    return parameters

# %%
def linear_forward(A_prev,W,b):

    Z=np.dot(W,A_prev)+b
    cache=(A_prev,W,b)
    return Z,cache

# %%
def linear_activation_forward(A_prev,W,b,activation):
    
    if activation=="sigmoid":
        Z,linear_cache=linear_forward(A_prev,W,b)
        A,activation_cache=sigmoid(Z)
    if activation=="relu":
        Z,linear_cache=linear_forward(A_prev,W,b)
        A,activation_cache=relu(Z)
   
    cache=(linear_cache,activation_cache)
    return A,cache

# %%
def L_model_forward(X,parameters,keep_prob=1):
    np.random.seed(1)
    caches=[]
    dropouts=[]
    layers=len(parameters)//2
    A=X
    for l in range(1,layers):
        A_prev = A 
        A,cache=linear_activation_forward(A_prev,parameters["W"+str(l)],parameters["b"+str(l)],"relu")
        
        #add dropout from 1 to layers-1,ignore input and output layer
        if keep_prob<1:
            dropout=np.random.rand(A.shape[0],A.shape[1])
            
            dropout=(dropout<keep_prob)
            A=(A*dropout)/keep_prob
            dropouts.append(dropout)
        caches.append(cache)
        
    AL,cache=linear_activation_forward(A,parameters["W"+str(layers)],parameters["b"+str(layers)],"sigmoid")
    caches.append(cache)
    return AL,caches,dropouts

# %%
def compute_cost(AL,Y,parameters,lambd):
    m=Y.shape[1]
    cost = -np.dot(Y,np.log(AL).T) - np.dot(1-Y, np.log(1-AL).T)
    cost=np.squeeze(cost)/m
    
    #add W in all layers
    L=len(parameters)//2
    R=0
    for l in range(1,L+1):
        R+=np.sum(np.square(parameters["W"+str(l)]))
    lastcost=cost+lambd*R/(2*m)
    return lastcost

# %%
def sigmoid_backward(dA,activation_cache):
    Z=activation_cache
    s=1/(1+np.exp(-Z))
    dZ=dA*s*(1-s)
    return dZ

# %%
def relu_backward(dA,activation_cache):
    
    Z=activation_cache
    dZ=np.array(dA,copy=True)
    dZ[Z<=0]=0
    return dZ

# %%
def linear_backward(dZ,linear_cache,lambd):
    A_prev,W,b=linear_cache
    m=A_prev.shape[1]
    
    dW=(np.dot(dZ,A_prev.T)+lambd*W)/m
    db=np.sum(dZ,axis=1,keepdims=True)/m
    dA_prev=np.dot(W.T,dZ)
    return dA_prev,dW,db

# %%
def linear_activation_backward(dA,cache,activation,lambd):
    
    
    linear_cache,activation_cache=cache
   
    if activation=="sigmoid":
        dZ=sigmoid_backward(dA,activation_cache)
    elif activation=="relu":
        dZ=relu_backward(dA,activation_cache)
    dA_prev,dW,db=linear_backward(dZ,linear_cache,lambd)

    return dA_prev,dW,db

# %%
def L_model_backward(AL,Y,caches,dropouts,lambd,keep_prob):
    
    grads={}
    L=len(caches)
    
    dAL = - (np.divide(Y, AL) - np.divide(1 - Y, 1 - AL))
    
    current_cache=caches[L-1]
    grads["dA"+str(L-1)],grads["dW"+str(L)],grads["db"+str(L)]=linear_activation_backward(dAL,current_cache,"sigmoid",lambd)
    if keep_prob<1:
        grads["dA"+str(L-1)]=(grads["dA"+str(L-1)]*dropouts[L-2])/keep_prob
        #print("dA="+str(L-1)+str(grads["dA"+str(L-1)]))
    for l in reversed(range(L-1)):
        current_cache=caches[l]
        grads["dA"+str(l)],grads["dW"+str(l+1)],grads["db"+str(l+1)]=linear_activation_backward(grads["dA"+str(l+1)],current_cache,"relu",lambd)
        if keep_prob<1 and l>0:
            
            grads["dA"+str(l)]=(grads["dA"+str(l)]*dropouts[l-1])/keep_prob
           # print("dA="+str(l)+str(grads["dA"+str(l)]))
    return grads

# %%
def update_parameters(parameters,grads,learning_rate):
    
    L=len(parameters)//2
    
    for l in range(1,L+1):
        parameters["W"+str(l)]=parameters["W"+str(l)]-learning_rate*grads["dW"+str(l)]
        parameters["b"+str(l)]=parameters["b"+str(l)]-learning_rate*grads["db"+str(l)]
        
    return parameters

# %%
def L_layer_model(X,Y,layers_dims,learning_rate=0.3,num_iterations=3000,print_cost=False,lambd = 0,keep_prob = 1):
    np.random.seed(1)
    costs=[]
    parameters=initialize_parameter_deep(layers_dims)
    
    
    for i in range(0,num_iterations):
        
        AL,caches,dropouts=L_model_forward(X,parameters,keep_prob)
        
        cost=compute_cost(AL,Y,parameters,lambd)
        grads=L_model_backward(AL,Y,caches,dropouts,lambd,keep_prob)
        parameters=update_parameters(parameters,grads,learning_rate)
        if print_cost and i%1000==0:
            print("interations"+str(i)+","+str(cost))
        if print_cost and i%1000==0:
            costs.append(cost)
    plt.plot(np.squeeze(costs))
    plt.ylabel('cost')
    plt.xlabel('iterations (x1,000)')
    plt.title("Learning rate =" + str(learning_rate))
    plt.show()
    return parameters

# %%
def predict(X,y,parameters,):
    
    AL,caches,dropouts=L_model_forward(X,parameters)
    m=X.shape[1]
    yhat=np.round(AL)
    
    print("Accuracy:"+str(np.sum(yhat==y)/m))
    return yhat

# %%
layers_dims=[2,20,3,1]

# %%
parameters=L_layer_model(train_X,train_Y,layers_dims,learning_rate=0.3,num_iterations=30000,print_cost=True)
pred_train = predict(train_X, train_Y, parameters,)
pred_test = predict(test_X, test_Y, parameters)

# %%
parameters=L_layer_model(train_X,train_Y,layers_dims,learning_rate=0.3,num_iterations=30000,print_cost=True,lambd=0.7)
pred_train = predict(train_X, train_Y, parameters)
pred_test = predict(test_X, test_Y, parameters)
# Out:
# interations0,0.6974484493131264
# interations1000,0.27304563479326766
# interations2000,0.26985760798332925
# interations3000,0.269508280641266
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-b8c2d3f50fc4> in <module>()
# ----> 1 parameters=L_layer_model(train_X,train_Y,layers_dims,learning_rate=0.3,num_iterations=30000,print_cost=True,lambd=0.7)
#       2 pred_train = predict(train_X, train_Y, parameters)
#       3 pred_test = predict(test_X, test_Y, parameters)
#
# <ipython-input-78-d1c618dbbb19> in L_layer_model(X, Y, layers_dims, learning_rate, num_iterations, print_cost, lambd, keep_prob)
#       7     for i in range(0,num_iterations):
#       8
# ----> 9         AL,caches,dropouts=L_model_forward(X,parameters,keep_prob)
#      10
#      11         cost=compute_cost(AL,Y,parameters,lambd)
#
# <ipython-input-52-cb7262ed135e> in L_model_forward(X, parameters, keep_prob)
#       7     for l in range(1,layers):
#       8         A_prev = A
# ----> 9         A,cache=linear_activation_forward(A_prev,parameters["W"+str(l)],parameters["b"+str(l)],"relu")
#      10
#      11         #add dropout from 1 to layers-1,ignore input and output layer
#
# <ipython-input-51-96d9676e7f5d> in linear_activation_forward(A_prev, W, b, activation)
#       6     if activation=="relu":
#       7         Z,linear_cache=linear_forward(A_prev,W,b)
# ----> 8         A,activation_cache=relu(Z)
#       9
#      10     cache=(linear_cache,activation_cache)
#
# <ipython-input-48-85de77741386> in relu(Z)
#       1 def relu(Z):
# ----> 2     A=np.maximum(0,Z)
#       3     cache=Z
#       4     return A,Z
#
# KeyboardInterrupt:

# %%
parameters=L_layer_model(train_X,train_Y,layers_dims,learning_rate=0.3,num_iterations=30000,print_cost=True,lambd=0,keep_prob=0.86)
pred_train = predict(train_X, train_Y, parameters)
pred_test = predict(test_X, test_Y, parameters)
# Out:
# interations0,0.6543912405149825
# interations1000,0.1759784892976791
# interations2000,0.10396707442900775
# interations3000,0.07661297787357771
# d:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """
# d:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in multiply
#   """
# d:\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: RuntimeWarning: invalid value encountered in true_divide
#
# d:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in maximum
#
# d:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in less_equal
#   """
# interations4000,nan
# interations5000,nan
# interations6000,nan
# interations7000,nan
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-90-39a42a6ca998> in <module>()
# ----> 1 parameters=L_layer_model(train_X,train_Y,layers_dims,learning_rate=0.3,num_iterations=30000,print_cost=True,lambd=0,keep_prob=0.86)
#       2 pred_train = predict(train_X, train_Y, parameters)
#       3 pred_test = predict(test_X, test_Y, parameters)
#
# <ipython-input-78-d1c618dbbb19> in L_layer_model(X, Y, layers_dims, learning_rate, num_iterations, print_cost, lambd, keep_prob)
#      10
#      11         cost=compute_cost(AL,Y,parameters,lambd)
# ---> 12         grads=L_model_backward(AL,Y,caches,dropouts,lambd,keep_prob)
#      13         parameters=update_parameters(parameters,grads,learning_rate)
#      14         if print_cost and i%1000==0:
#
# <ipython-input-67-8db20cf424e7> in L_model_backward(AL, Y, caches, dropouts, lambd, keep_prob)
#      13     for l in reversed(range(L-1)):
#      14         current_cache=caches[l]
# ---> 15         grads["dA"+str(l)],grads["dW"+str(l+1)],grads["db"+str(l+1)]=linear_activation_backward(grads["dA"+str(l+1)],current_cache,"relu",lambd)
#      16         if keep_prob<1 and l>0:
#      17
#
# <ipython-input-58-260eff5fe7bb> in linear_activation_backward(dA, cache, activation, lambd)
#       8     elif activation=="relu":
#       9         dZ=relu_backward(dA,activation_cache)
# ---> 10     dA_prev,dW,db=linear_backward(dZ,linear_cache,lambd)
#      11
#      12     return dA_prev,dW,db
#
# <ipython-input-57-5c3a13567905> in linear_backward(dZ, linear_cache, lambd)
#       3     m=A_prev.shape[1]
#       4
# ----> 5     dW=(np.dot(dZ,A_prev.T)+lambd*W)/m
#       6     db=np.sum(dZ,axis=1,keepdims=True)/m
#       7     dA_prev=np.dot(W.T,dZ)
#
# KeyboardInterrupt:
